# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Proyecto: Grafo de los persponajes de The Last of Us
#
# Mi proyecto se centrara en realizar un grafos sobre las relaciones de los personajes de la saga de The Last of Us incluyendo las partes I y II además del DLC Left Behind, se realizaran grafos individuales de cada juego de la saga y finalmente un grafo que incluya todos los personajes de los grafos anteriores. Dentro de cada grafo veremos a los personajes como nodos y luego insertaremos vertices que los unan dependiendo si es que tienen una relación directa o indirecta (ya sean amigos, enemigos, aliados o simplemente encontremos notas que los relacionen con la historia del juego). Luego dibujaremos el grafo y veremos los conjuntos de nodos y vertices ordenados que tenemos dentro de nuestros grafos, vecinos que están conectados al nodo con más conexiones, los grados de todos los nodos y la excentricidad de estos mismos.
#
# Cabe recalcar que muchos de los personajes no cuentan o no se les menciona su apellido, al igual que reduje los nombres dentro de los grafos para una mejor vista de este.

# %% [markdown]
# <img src = "https://thelastofus.es/wp-content/uploads/2023/11/portada-TLOU-parte-1-y-2.jpg"
#    style="display: block; margin-left: auto; margin-right: auto;"/>

# %% [markdown]
# ## Sinopsis
#
# ### The Last of Us Part I
#
# En una civilización devastada, donde los infectados y los empedernidos sobrevivientes proliferan, Joel, un protagonista cansado, es contratado para rescatar de contrabando a una niña de 14 años llamada Ellie de una zona de cuarentena militar. Sin embargo, lo que comienza como un pequeño trabajo pronto se transforma en una brutal travesía por todo el país.
#
# <img src = "https://www.mundodeportivo.com/alfabeta/hero/2022/08/The-Last-of-Us%E2%84%A2-Parte-I_20220828234106.jpg?width=1200"
#    style="display: block; margin-left: auto; margin-right: auto;"/>
#
# #### Personajes
#
# ##### Joel Miller
#
# Antes del brote, Joel vivía en Texas y trabajaba como constructor. Tenía una hija llamada Sarah, a quien criaba como padre soltero. La noche del brote, Joel pierde a Sarah en un tiroteo con un soldado, un evento que lo marca profundamente.
#
# einte años después del brote, Joel se ha convertido en un hombre endurecido y cínico. Vive en una zona de cuarentena controlada por el ejército y se dedica al contrabando y otras actividades ilícitas para sobrevivir.
#
# Joel recibe la misión de escoltar a una joven llamada Ellie a través de los Estados Unidos devastados. Ellie es inmune al hongo Cordyceps, y podría ser la clave para desarrollar una cura. A lo largo del viaje, Joel y Ellie desarrollan un vínculo padre-hija muy fuerte.
#
# ##### Sarah Miller
#
# Era la hija de 12 años de Joel antes del brote de infección cerebral por Cordyceps.
# Sarah nació en el 2001, de Joel Miller y una madre desconocida. La madre de Sarah y Joel estuvieron casados "durante un tiempo", pero ella dejó a Joel poco después del nacimiento de Sarah. Antes del brote, vivía una vida cotidiana normal en el área de Austin, Texas, con su padre Joel.
#
# ##### Tommy Miller
#
# Aunque comparte la aspereza y la determinación de su hermano Joel, Tommy se distingue por una personalidad impulsiva, compasiva y optimista. Después de un tiempo luchando junto a las Luciérnagas, conoce a su futura esposa, Maria, y su comunidad en Jackson, Wyoming. Con este nuevo sentido para sus valores, busca crear una vida rica y significativa a pesar de unas circunstancias desalentadoras.
#
# ##### Jimmy Cooper
#
# No se sabe mucho sobre la vida de Jimmy antes del día del brote, excepto que él era el vecino de Joel y Sarah y tenía un trabajo en la ciudad. Es probable que él tuviera una familia y que ellos también estuvieran infectados, ya que Joel se refiere a algo que está mal con "los Coopers".
# %%
TheLastofUsI.add_nodes_from(["Joel", "Sarah", "Tommy", "Jimmy", "Tess", "Robert", "Marlene", "Anna", "Ellie", "Bill", "Frank", "Henry", "Sam", "Maria", "Seth", "Buckley", "Callus", "David", "James", "Scully", "Ethan", "Jerry", "Kari"])

# %%
TheLastofUsI.add_edges_from([
    ("Joel", "Sarah"), ("Joel", "Tommy"), ("Joel", "Jimmy"), ("Joel", "Tess"), 
    ("Joel", "Ellie"), ("Joel", "Bill"), ("Joel", "Frank"), 
    ("Joel", "Henry"), ("Joel", "Sam"), ("Sarah", "Tommy"), 
    ("Sarah", "Jimmy"), ("Tommy", "Marlene"), ("Tommy", "Maria"), 
    ("Tommy", "Buckley"), ("Tommy", "Seth"), ("Tess", "Robert"), ("Tess", "Bill"), 
    ("Robert", "Marlene"), ("Marlene", "Anna"), ("Marlene", "Ellie"), 
    ("Marlene", "Ethan"), ("Marlene", "Jerry"), ("Marlene", "Kari"), 
    ("Anna", "Ellie"), ("Ellie", "Callus"), ("Ellie", "David"), 
    ("Ellie", "Tess"), ("Bill", "Frank"), ("Henry", "Sam"), 
    ("Maria", "Seth"), ("David", "James"), ("David", "Scully"), 
    ("Jerry", "Ethan"), ("Jerry", "Kari")
])

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(TheLastofUsI, seed=42)
nx.draw(TheLastofUsI, pos, with_labels=True, node_color="green", node_size=1500, font_color="white", font_size=8, edge_color="gray")
plt.title('Grafo de Personajes de The Last of Us Parte 1')
plt.show()

# %% [markdown]
# #### Visualizar nodos

# %%
list(TheLastofUsI.nodes())
# Out:
# ['Joel',
#  'Sarah',
#  'Tommy',
#  'Jimmy',
#  'Tess',
#  'Robert',
#  'Marlene',
#  'Anna',
#  'Ellie',
#  'Bill',
#  'Frank',
#  'Henry',
#  'Sam',
#  'Maria',
#  'Seth',
#  'Buckley',
#  'Callus',
#  'David',
#  'James',
#  'Scully',
#  'Ethan',
#  'Jerry',
#  'Kari']

# %% [markdown]
# #### Visualizar vértices

# %%
list(TheLastofUsI.edges())
# Out:
# [('Joel', 'Sarah'),
#  ('Joel', 'Tommy'),
#  ('Joel', 'Jimmy'),
#  ('Joel', 'Tess'),
#  ('Joel', 'Ellie'),
#  ('Joel', 'Bill'),
#  ('Joel', 'Frank'),
#  ('Joel', 'Henry'),
#  ('Joel', 'Sam'),
#  ('Sarah', 'Tommy'),
#  ('Sarah', 'Jimmy'),
#  ('Tommy', 'Marlene'),
#  ('Tommy', 'Maria'),
#  ('Tommy', 'Buckley'),
#  ('Tommy', 'Seth'),
#  ('Tess', 'Robert'),
#  ('Tess', 'Bill'),
#  ('Tess', 'Ellie'),
#  ('Robert', 'Marlene'),
#  ('Marlene', 'Anna'),
#  ('Marlene', 'Ellie'),
#  ('Marlene', 'Ethan'),
#  ('Marlene', 'Jerry'),
#  ('Marlene', 'Kari'),
#  ('Anna', 'Ellie'),
#  ('Ellie', 'Callus'),
#  ('Ellie', 'David'),
#  ('Bill', 'Frank'),
#  ('Henry', 'Sam'),
#  ('Maria', 'Seth'),
#  ('David', 'James'),
#  ('David', 'Scully'),
#  ('Ethan', 'Jerry'),
#  ('Jerry', 'Kari')]

# %% [markdown]
# #### Primera forma de visualizar vecinos

# %%
list(TheLastofUsI.adj["Joel"])
# Out:
# ['Sarah', 'Tommy', 'Jimmy', 'Tess', 'Ellie', 'Bill', 'Frank', 'Henry', 'Sam']

# %% [markdown]
# #### Segunda forma de visualizar vecinos

# %%
list(TheLastofUsI.neighbors("Tess"))
# Out:
# ['Joel', 'Robert', 'Bill', 'Ellie']

# %% [markdown]
# #### Visualizar grados de nodos

# %%
list(TheLastofUsI.degree())
# Out:
# [('Joel', 9),
#  ('Sarah', 3),
#  ('Tommy', 6),
#  ('Jimmy', 2),
#  ('Tess', 4),
#  ('Robert', 2),
#  ('Marlene', 7),
#  ('Anna', 2),
#  ('Ellie', 6),
#  ('Bill', 3),
#  ('Frank', 2),
#  ('Henry', 2),
#  ('Sam', 2),
#  ('Maria', 2),
#  ('Seth', 2),
#  ('Buckley', 1),
#  ('Callus', 1),
#  ('David', 3),
#  ('James', 1),
#  ('Scully', 1),
#  ('Ethan', 2),
#  ('Jerry', 3),
#  ('Kari', 2)]

# %% [markdown]
# #### Visualizar excentricidad

# %%
dict(nx.eccentricity(TheLastofUsI))
# Out:
# {'Joel': 3,
#  'Sarah': 4,
#  'Tommy': 4,
#  'Jimmy': 4,
#  'Tess': 3,
#  'Robert': 4,
#  'Marlene': 3,
#  'Anna': 3,
#  'Ellie': 3,
#  'Bill': 4,
#  'Frank': 4,
#  'Henry': 4,
#  'Sam': 4,
#  'Maria': 5,
#  'Seth': 5,
#  'Buckley': 5,
#  'Callus': 4,
#  'David': 4,
#  'James': 5,
#  'Scully': 5,
#  'Ethan': 4,
#  'Jerry': 4,
#  'Kari': 4}

# %% [markdown]
# #### Visualizar radio

# %%
radio = nx.radius(TheLastofUsI)

print(f'El radio del grafo es: {radio}')
# Out:
# El radio del grafo es: 3

# %% [markdown]
# #### Visualizar diametro

# %%
diametro = nx.diameter(TheLastofUsI)

print(f'El diámetro del grafo es: {diametro}')
# Out:
# El diámetro del grafo es: 5

# %% [markdown]
# #### Visualizar centro

# %%
centro = nx.center(TheLastofUsI)

print(f'El centro del grafo es: {centro}')
# Out:
# El centro del grafo es: ['Joel', 'Tess', 'Marlene', 'Anna', 'Ellie']

# %% [markdown]
# ### Left Behind
#
# Se desarrolla la relación entre Ellie y Riley, su mejor amiga, que en algún momento fue su mentora en el internado militar en el que crecieron juntas. Después de ausentarse varias semanas, Riley regresa y trae consigo una sorprendente revelación sobre su paradero. Ellie y Riley se escapan de la escuela por última vez, y esto desencadenará una serie de eventos que cambiarán sus vidas para siempre.
#
# <img src = "https://ew.com/thmb/f_S5B0xTCg_DJqR5Mfvw7axbiMM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()
TheLastofUs_LeftBehind.add_nodes_from(["Joel", "Marlene", "Anna", "Ellie", "Callus", "Riley", "Winston", "Princesa", "Eugene", "Larry", "Sean", "Regan"])

# %%
TheLastofUs_LeftBehind.add_edges_from([
    ("Joel", "Ellie"), ("Ellie", "Callus"), ("Ellie", "Marlene"), ("Ellie", "Anna"), 
    ("Ellie", "Riley"), ("Ellie", "Winston"), ("Ellie", "Eugene"), ("Ellie", "Larry"), 
    ("Ellie", "Sean"), ("Ellie", "Regan"), ("Riley", "Winston"), ("Riley", "Marlene"), 
    ("Marlene", "Anna"), ("Winston", "Princesa"), ("Eugene", "Sean"), ("Eugene", "Regan"), 
    ("Eugene", "Larry"), ("Sean", "Eugene"), ("Sean", "Regan"), ("Regan", "Eugene"), 
    ("Regan", "Sean"), ("Regan", "Larry"), ("Larry", "Eugene")
])

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(TheLastofUs_LeftBehind, seed=42)
nx.draw(TheLastofUs_LeftBehind, pos, with_labels=True, node_color="green", node_size=1500, font_color="white", font_size=8, edge_color="gray")
plt.title('Grafo de Personajes de The Last of Us: Left Behind')
plt.show()

# %%
list(TheLastofUs_LeftBehind.nodes())
# Out:
# ['Joel',
#  'Marlene',
#  'Anna',
#  'Ellie',
#  'Callus',
#  'Riley',
#  'Winston',
#  'Princesa',
#  'Eugene',
#  'Larry',
#  'Sean',
#  'Regan']

# %%
list(TheLastofUs_LeftBehind.edges())
# Out:
# [('Joel', 'Ellie'),
#  ('Marlene', 'Ellie'),
#  ('Marlene', 'Riley'),
#  ('Marlene', 'Anna'),
#  ('Anna', 'Ellie'),
#  ('Ellie', 'Callus'),
#  ('Ellie', 'Riley'),
#  ('Ellie', 'Winston'),
#  ('Ellie', 'Eugene'),
#  ('Ellie', 'Larry'),
#  ('Ellie', 'Sean'),
#  ('Ellie', 'Regan'),
#  ('Riley', 'Winston'),
#  ('Winston', 'Princesa'),
#  ('Eugene', 'Sean'),
#  ('Eugene', 'Regan'),
#  ('Eugene', 'Larry'),
#  ('Larry', 'Regan'),
#  ('Sean', 'Regan')]

# %%
list(TheLastofUs_LeftBehind.adj["Ellie"])
# Out:
# ['Joel',
#  'Callus',
#  'Marlene',
#  'Anna',
#  'Riley',
#  'Winston',
#  'Eugene',
#  'Larry',
#  'Sean',
#  'Regan']

# %%
list(TheLastofUs_LeftBehind.neighbors("Marlene"))
# Out:
# ['Ellie', 'Riley', 'Anna']

# %%
list(TheLastofUs_LeftBehind.degree())
# Out:
# [('Joel', 1),
#  ('Marlene', 3),
#  ('Anna', 2),
#  ('Ellie', 10),
#  ('Callus', 1),
#  ('Riley', 3),
#  ('Winston', 3),
#  ('Princesa', 1),
#  ('Eugene', 4),
#  ('Larry', 3),
#  ('Sean', 3),
#  ('Regan', 4)]

# %%
dict(nx.eccentricity(TheLastofUs_LeftBehind))
# Out:
# {'Joel': 3,
#  'Marlene': 3,
#  'Anna': 3,
#  'Ellie': 2,
#  'Callus': 3,
#  'Riley': 2,
#  'Winston': 2,
#  'Princesa': 3,
#  'Eugene': 3,
#  'Larry': 3,
#  'Sean': 3,
#  'Regan': 3}

# %% [markdown]
# #### Visualizar radio

# %%
radio = (nx.radius(TheLastofUs_LeftBehind))

print(f'El radio del grafo es: {radio}')
# Out:
# El radio del grafo es: 2

# %% [markdown]
# #### Visualizar diametro

# %%
diametro = (nx.diameter(TheLastofUs_LeftBehind))

print(f'El diametro del grafo es: {diametro}')
# Out:
# El diametro del grafo es: 3

# %% [markdown]
# #### Visualizar centro

# %%
centro = (nx.center(TheLastofUs_LeftBehind))

print(f'El centro del grafo es: {centro}')
# Out:
# El centro del grafo es: ['Ellie', 'Riley', 'Winston']

# %% [markdown]
# ### The Last of Us Part II
#
# Cinco años después de su peligroso viaje a través de unos Estados Unidos pospandemia, Ellie y Joel logran establecerse en Jackson, Wyoming. Vivir entre una próspera comunidad de sobrevivientes les ha concedido paz y estabilidad, a pesar de la amenaza constante de los infectados y de otros sobrevivientes más desesperados.
#
# Cuando un evento traumático interrumpe esa paz, Ellie se embarca en un viaje incesante para obtener justicia y llegar a un cierre. A medida que caza a los responsables uno por uno, deberá enfrentarse a las devastadoras repercusiones físicas y emocionales de sus acciones.
#
# <img src = "https://m.media-amazon.com/images/I/81BojL1A2oL._AC_UF1000,1000_QL80_.jpg"
#    style="display: block; margin-left: auto; margin-right: auto;"/>
#
# #### Personajes
#
# **Ellie Williams**
#
# En "The Last of Us Part II," Ellie ha crecido desde su aparición en el primer juego. Ahora tiene 19 años y vive en Jackson, Wyoming, una comunidad relativamente segura junto a Joel, Tommy. Conoce a varias personas en el transcurso de su vida dentro de la comunidad como su Ex Cat, su actual novia Dina y su amigo Jesse.
#
# **Joel Miller**
#
# En "The Last of Us Part II," Joel vive en Jackson, Wyoming, en una comunidad segura junto con Ellie. Su principal motivación es proteger a Ellie y mantener la seguridad de la comunidad. A lo largo de los años, Joel ha intentado reconstruir una vida relativamente normal y pacífica.
#
# **Tommy Miller**
#
# Tommy es el hermano menor de Joel y uno de los líderes de la comunidad de Jackson, Wyoming, donde viven en relativa seguridad junto con Ellie. Su relación con Joel es cercana y fraternal, y tienen un fuerte vínculo basado en su historia compartida de supervivencia.
#
# **Maria Miller**
#
# Maria es la esposa de Tommy Miller y una de las líderes de la comunidad de Jackson, Wyoming. Su liderazgo y fortaleza han sido fundamentales para mantener la seguridad y el bienestar de los habitantes de Jackson.
#
# **Dina**
#
# Dina es una joven residente de la comunidad de Jackson, Wyoming. Antes de los eventos del juego, Dina creció en un entorno similar al de Ellie, enfrentando las dificultades del mundo post-apocalíptico. Ella y Ellie se conocen desde hace algún tiempo y tienen una amistad cercana que se desarrolla en una relación romántica.
#
# **Talia**
#
# La presencia de Talia se siente principalmente a través de las conversaciones de Dina con Ellie y otros personajes, así como en los recuerdos de Dina. Dina menciona a Talia en contextos que resaltan la importancia de la familia y las pérdidas sufridas en el mundo post-apocalíptico.
#
# **JJ**
#
# JJ es el hijo de Dina y Jesse, nacido durante los eventos del juego. Su nombre completo no se revela, pero se supone que JJ es un apodo que combina las iniciales de Jesse y Joel, en honor tanto a su padre biológico como a Joel Miller, quien fue una figura paterna importante para Ellie.
#
# **Jesse**
#
# Jesse es un joven residente de la comunidad de Jackson, Wyoming. Es amigo cercano de Ellie y Dina, y anteriormente tuvo una relación romántica con Dina, de la cual quedó embarazada. Jesse es conocido por su carácter valiente, su lealtad y su habilidad para enfrentar los desafíos del mundo post-apocalíptico.
#
# **Cat**
#
# Cat es una residente de la comunidad de Jackson, Wyoming, donde vive junto con otros supervivientes bajo el liderazgo de Tommy y Maria. Aunque no se conocen muchos detalles específicos sobre su pasado, sabemos que es la ex-novia de Ellie y que realizó su tatuaje en su brazo, es parte integral de la vida comunitaria en Jackson.
#
# **Seth**
#
# Seth es un residente de la comunidad de Jackson, Wyoming, donde vive junto con otros sobrevivientes bajo el liderazgo de Tommy y Maria. Es conocido por ser un hombre mayor y gruñón que tiene una historia problemática con algunos miembros de la comunidad.
#
# **Eugene Liden**
#
# Eugene Linden era un residente de la comunidad de Jackson, Wyoming, y uno de los supervivientes más hábiles y conocedores en el uso de la tecnología. Antes de los eventos del juego, Eugene era conocido por ser un experto en electrónica y por ayudar a mantener la infraestructura tecnológica de la comunidad.
#
# **Shimmer**
#
# Shimmer es el caballo de Ellie y su compañero constante durante gran parte de su travesía por Seattle. No se revela mucho sobre el origen de Shimmer, pero se presume que ha sido un fiel compañero de Ellie desde antes de los eventos del juego.
#
# **Abby Anderson**
#
# Abby es introducida como una nueva protagonista en la historia, con una trama paralela que se entrelaza con la de Ellie. Antes de los eventos del juego, Abby era una soldado de los WLF (Washington Liberation Front), una de las facciones en guerra por el control de Seattle. Es hija del Dr. Jerry Anderson, uno de los científicos que trabajaba en la cura para la infección fungal que provocó el apocalipsis.
#
# **Jerry Anderson**
#
# El Dr. Jerry Anderson era un científico prominente y parte del equipo de investigación que trabajaba en una posible cura para la infección fungal que devastó el mundo y provocó el apocalipsis en "The Last of Us". Era el padre de Abby Anderson y un personaje clave en el contexto de la búsqueda de una cura para la infección.
#
# **Owen Moore**
#
# Owen Moore es presentado como un miembro de los WLF (Washington Liberation Front), una de las facciones en conflicto en Seattle. Antes de los eventos del juego, Owen era amigo cercano y compañero de Abby Anderson, y también tenía una relación romántica con ella.
#
# **Mel**
#
# Mel es una médica y miembro de los WLF (Washington Liberation Front), una de las facciones en conflicto en Seattle. Ella trabaja en el campo médico junto con su pareja Owen y es parte integral de la comunidad de los WLF.
#
# **Nora**
#
# Nora es miembro de los WLF (Washington Liberation Front), una facción en conflicto en Seattle. Ella desempeña un papel importante en la estructura de mando y operaciones de los WLF, especialmente en su sede central en Seattle.
#
# **Whitney Sato**
#
# Whitney Sato es presentada como una amiga cercana de Abby Anderson dentro de los WLF. Aunque no se revelan muchos detalles específicos sobre su trasfondo o historia personal, su relación con Abby subraya la importancia de las conexiones personales y las amistades en un entorno tan hostil como Seattle.
#
# **Jordan**
#
# Jordan es uno de los miembros prominentes de los WLF y tiene una posición de autoridad dentro de la facción. Aunque no se revelan muchos detalles específicos sobre su historia personal, su papel dentro de los WLF sugiere que es respetado y tiene influencia entre sus miembros.
#
# **Manny Alvarez**
#
# En algún momento después del brote de infección cerebral por Cordyceps, Hugo estaba en la zona de cuarentena de Seattle y no le gustaba vivir bajo FEDRA y el gobierno militar. Se unió al grupo de milicias conocido como el Frente de Liberación de Washington y trabajó con los líderes Jason y Emma Patterson. Solía distribuir propaganda anti-FEDRA. Dado que, a diferencia de los otros líderes de la WLF, las acciones de Hugo fueron bastante dóciles, el Sargento Ward no lo consideró un objetivo prioritario como lo hacía con otros miembros. Independientemente, todavía lo buscaban por sus crímenes.
#
# **Lev**
#
# Lev es introducido como un joven Serafita que, debido a circunstancias complicadas, se ve obligado a abandonar su comunidad. Como miembro de los Serafitas, originalmente fue asignado a un papel tradicional de género femenino, pero decidió vivir como un hombre, lo que lo llevó a enfrentarse a la desaprobación y persecución dentro de su comunidad.
#
# **Yara**
#
# Yara es introducida como la hermana mayor de Lev, ambos pertenecientes inicialmente a los Serafitas. A lo largo de la historia, se revela que Yara y Lev escaparon de los Serafitas debido a circunstancias relacionadas con la identidad de género de Lev y su deseo de vivir como un hombre, lo cual es contrario a las normas estrictas de su comunidad.
#
# **Madre de Lev y Yara**
#
# La madre de Lev y Yara es mencionada como una figura importante dentro de los Serafitas, la facción religiosa a la que pertenecen inicialmente. Su papel parece ser significativo en la crianza y la educación de sus hijos dentro de la estricta sociedad de los Serafitas, donde las normas y tradiciones tienen un peso considerable.
#
# **Profeta Serafita**
#
# La Profeta Serafita es una figura misteriosa y carismática que lidera a los Serafitas. Es venerada por su comunidad como una líder espiritual y política, tomando decisiones que afectan profundamente a sus seguidores. Su influencia se extiende más allá de la esfera espiritual, afectando la política y las decisiones estratégicas de los Serafitas en su conflicto con los WLF y otros grupos en Seattle.
#
# Los Serafitas son una comunidad religiosa que sigue estrictamente las enseñanzas de su Profeta. Viven en una isla frente a la costa de Seattle y han desarrollado una sociedad basada en rituales religiosos y tradiciones estrictas. Se distinguen por su vestimenta y su lenguaje, además de ser conocidos por su habilidad en la navegación marítima y su uso de arcos y flechas.
#
# **Clan Víbora**
#
# El Clan Víbora es una facción de saqueadores y criminales que se caracterizan por su brutalidad y falta de escrúpulos. Operan en las áreas periféricas de Seattle, buscando recursos y haciendo lo que sea necesario para sobrevivir en un mundo post-apocalíptico.

# %%
TheLastofUsII = nx.Graph()

# %%
TheLastofUsII.add_nodes_from(["Ellie", "Joel", "Tommy", "Maria", "Dina", "Talia", "JJ", "Jesse", "Cat", "Seth", "Eugene", "Shimmer", "Abby", "Jerry", "Owen", "Mel", "Nora", "Whitney", "Jordan", "Manny", "Nick", "Leah", "Alice", "Bear", "Isaac", "Emma", "Alison", "Marcus", "Luis", "Hugo", "Lev", "Yara", "Madre L. y Y.", "Serafitas", "Clan Víbora"])

# %%
TheLastofUsII.add_edges_from([
    ("Ellie", "Joel"), ("Ellie", "Tommy"), ("Ellie", "Maria"), ("Ellie", "Dina"), 
    ("Ellie", "Jesse"), ("Ellie", "JJ"), ("Ellie", "Cat"), ("Ellie", "Seth"),
    ("Ellie", "Shimmer"), ("Ellie", "Abby"), ("Joel", "Tommy"), ("Tommy", "Maria"), 
    ("Tommy", "Eugene"), ("Dina", "Talia"), ("Dina", "JJ"), ("Dina", "Jesse"), 
    ("Abby", "Jerry"), ("Abby", "Owen"), ("Abby", "Mel"), ("Abby", "Owen"),
    ("Abby", "Nora"), ("Abby", "Whitney"), ("Abby", "Jordan"), ("Abby", "Manny"),
    ("Abby", "Nick"), ("Abby", "Alice"), ("Abby", "Bear"), ("Abby", "Isaac"),
    ("Abby", "Lev"), ("Abby", "Yara"), ("Owen", "Mel"), ("Owen", "Manny"), ("Owen", "Jerry"),
    ("Owen", "Nora"), ("Owen", "Many"), ("Owen", "Whitney"), ("Owen", "Alice"), 
    ("Owen", "Jordan"), ("Owen", ",Manny"), ("Owen", "Nick"), ("Mel", "Nora"),
    ("Mel", "Jerry"), ("Mel", "Whitney"), ("Mel", "Jordan"), ("Mel", "Manny"), 
    ("Mel", "Alice"), ("Nora", "Whitney"), ("Nora", "Jordan"), ("Nora", "Manny"), 
    ("Nora", "Nick"), ("Whitney", "Jordan"), ("Whitney", "Manny"), ("Whitney", "Nick"),
    ("Jordan", "Manny"), ("Jordan", "Nick"), ("Jordan", "Leah"), ("Alice", "Bear"), 
    ("Isaac", "Emma"),  ("Isaac", "Alison"),  ("Isaac", "Marcus"),  ("Isaac", "Luis"),
    ("Isaac", "Hugo"), ("Emma", "Alison"), ("Emma", "Marcus"), ("Emma", "Luis"),
    ("Emma", "Hugo"), ("Alison", "Marcus"), ("Alison", "Luis"), ("Alison", "Hugo"),
    ("Marcus", "Luis"), ("Marcus", "Hugo"), ("Luis", "Hugo"), ("Lev", "Yara"),
    ("Lev", "Madre L. y Y."), ("Lev", "Mel"), ("Lev", "Owen"), ("Lev", "Alice"),
    ("Lev", "Clan Víbora"), ("Yara", "Madre L. y Y."), ("Yara", "Mel"), ("Yara", "Owen"), 
    ("Yara", "Alice"), ("Lev", "Serafitas"), ("Yara", "Serafitas"), 
    ("Madre L. y Y.", "Serafitas")
    
])

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(TheLastofUsII, seed=42)
nx.draw(TheLastofUsII, pos, with_labels=True, node_color="green", node_size=1100, font_color="white", font_size=8, edge_color="gray")
plt.title('Grafo de Personajes de The Last of Us II')
plt.show()

# %%
list(TheLastofUsII.nodes())
# Out:
# ['Ellie',
#  'Joel',
#  'Tommy',
#  'Maria',
#  'Dina',
#  'Talia',
#  'JJ',
#  'Jesse',
#  'Cat',
#  'Seth',
#  'Eugene',
#  'Shimmer',
#  'Abby',
#  'Jerry',
#  'Owen',
#  'Mel',
#  'Nora',
#  'Whitney',
#  'Jordan',
#  'Manny',
#  'Nick',
#  'Leah',
#  'Alice',
#  'Bear',
#  'Isaac',
#  'Emma',
#  'Alison',
#  'Marcus',
#  'Luis',
#  'Hugo',
#  'Lev',
#  'Yara',
#  'Madre L. y Y.',
#  'Serafitas',
#  'Clan Víbora']

# %%
list(TheLastofUsII.edges())
# Out:
# [('Ellie', 'Joel'),
#  ('Ellie', 'Tommy'),
#  ('Ellie', 'Maria'),
#  ('Ellie', 'Dina'),
#  ('Ellie', 'Jesse'),
#  ('Ellie', 'JJ'),
#  ('Ellie', 'Cat'),
#  ('Ellie', 'Seth'),
#  ('Ellie', 'Shimmer'),
#  ('Ellie', 'Abby'),
#  ('Joel', 'Tommy'),
#  ('Tommy', 'Maria'),
#  ('Tommy', 'Eugene'),
#  ('Dina', 'Talia'),
#  ('Dina', 'JJ'),
#  ('Dina', 'Jesse'),
#  ('Abby', 'Jerry'),
#  ('Abby', 'Owen'),
#  ('Abby', 'Mel'),
#  ('Abby', 'Nora'),
#  ('Abby', 'Whitney'),
#  ('Abby', 'Jordan'),
#  ('Abby', 'Manny'),
#  ('Abby', 'Nick'),
#  ('Abby', 'Alice'),
#  ('Abby', 'Bear'),
#  ('Abby', 'Isaac'),
#  ('Abby', 'Lev'),
#  ('Abby', 'Yara'),
#  ('Jerry', 'Owen'),
#  ('Jerry', 'Mel'),
#  ('Owen', 'Mel'),
#  ('Owen', 'Manny'),
#  ('Owen', 'Nora'),
#  ('Owen', 'Many'),
#  ('Owen', 'Whitney'),
#  ('Owen', 'Alice'),
#  ('Owen', 'Jordan'),
#  ('Owen', ',Manny'),
#  ('Owen', 'Nick'),
#  ('Owen', 'Lev'),
#  ('Owen', 'Yara'),
#  ('Mel', 'Nora'),
#  ('Mel', 'Whitney'),
#  ('Mel', 'Jordan'),
# ...

# %%
list(TheLastofUsII.adj["Ellie"])
# Out:
# ['Joel',
#  'Tommy',
#  'Maria',
#  'Dina',
#  'Jesse',
#  'JJ',
#  'Cat',
#  'Seth',
#  'Shimmer',
#  'Abby']

# %%
list(TheLastofUsII.neighbors("Abby"))
# Out:
# ['Ellie',
#  'Jerry',
#  'Owen',
#  'Mel',
#  'Nora',
#  'Whitney',
#  'Jordan',
#  'Manny',
#  'Nick',
#  'Alice',
#  'Bear',
#  'Isaac',
#  'Lev',
#  'Yara']

# %%
list(TheLastofUsII.degree())
# Out:
# [('Ellie', 10),
#  ('Joel', 2),
#  ('Tommy', 4),
#  ('Maria', 2),
#  ('Dina', 4),
#  ('Talia', 1),
#  ('JJ', 2),
#  ('Jesse', 2),
#  ('Cat', 1),
#  ('Seth', 1),
#  ('Eugene', 1),
#  ('Shimmer', 1),
#  ('Abby', 14),
#  ('Jerry', 3),
#  ('Owen', 13),
#  ('Mel', 10),
#  ('Nora', 7),
#  ('Whitney', 7),
#  ('Jordan', 8),
#  ('Manny', 6),
#  ('Nick', 5),
#  ('Leah', 1),
#  ('Alice', 6),
#  ('Bear', 2),
#  ('Isaac', 6),
#  ('Emma', 5),
#  ('Alison', 5),
#  ('Marcus', 5),
#  ('Luis', 5),
#  ('Hugo', 5),
#  ('Lev', 8),
#  ('Yara', 7),
#  ('Madre L. y Y.', 3),
#  ('Serafitas', 3),
#  ('Clan Víbora', 1),
#  ('Many', 1),
#  (',Manny', 1)]

# %%
dict(nx.eccentricity(TheLastofUsII))
# Out:
# {'Ellie': 3,
#  'Joel': 4,
#  'Tommy': 4,
#  'Maria': 4,
#  'Dina': 4,
#  'Talia': 5,
#  'JJ': 4,
#  'Jesse': 4,
#  'Cat': 4,
#  'Seth': 4,
#  'Eugene': 5,
#  'Shimmer': 4,
#  'Abby': 3,
#  'Jerry': 4,
#  'Owen': 4,
#  'Mel': 4,
#  'Nora': 4,
#  'Whitney': 4,
#  'Jordan': 4,
#  'Manny': 4,
#  'Nick': 4,
#  'Leah': 5,
#  'Alice': 4,
#  'Bear': 4,
#  'Isaac': 4,
#  'Emma': 5,
#  'Alison': 5,
#  'Marcus': 5,
#  'Luis': 5,
#  'Hugo': 5,
#  'Lev': 4,
#  'Yara': 4,
#  'Madre L. y Y.': 5,
#  'Serafitas': 5,
#  'Clan Víbora': 5,
#  'Many': 5,
#  ',Manny': 5}

# %% [markdown]
# #### Visualizar radio

# %%
radio = (nx.radius(TheLastofUsII))

print(f'El radio del grafo es: {radio}')
# Out:
# El radio del grafo es: 3

# %% [markdown]
# #### Visualizar diametro

# %%
diametro = (nx.radius(TheLastofUsII))

print(f'El diametro del grafo es: {diametro}')
# Out:
# El diametro del grafo es: 3

# %% [markdown]
# #### Visualizar centro

# %%
centro = (nx.center(TheLastofUsII))

print(f'El centro del grafo es: {centro}')
# Out:
# El centro del grafo es: ['Ellie', 'Abby']

# %% [markdown]
# ### Grafo de Todos los juegos
#
# Con ayuda de los grafos anteriores realizaremos un grafo que contenga a todos los personajes y sus relaciones

# %%
TheLastofUsF = nx.Graph()

# %%
TheLastofUsF.add_nodes_from(["Joel", "Sarah", "Tommy", "Jimmy", "Tess", "Robert", "Marlene", "Anna", "Ellie", "Bill", "Frank", "Henry", "Sam", "Maria", "Seth", "Buckley", "Callus", "David", "James", "Scully", "Ethan", "Jerry", "Kari", "Riley", "Winston", "Princesa", "Eugene1", "Larry", "Sean", "Regan", "Dina", "Talia", "JJ", "Jesse", "Cat", "Seth", "Eugene2", "Shimmer", "Abby", "Jerry", "Owen", "Mel", "Nora", "Whitney", "Jordan", "Manny", "Nick", "Leah", "Alice", "Bear", "Isaac", "Emma", "Alison", "Marcus", "Luis", "Hugo", "Lev", "Yara", "Madre L. y Y.", "Serafitas", "Clan Víbora"])

# %%
TheLastofUsF.add_edges_from([
    ("Ellie", "Joel"), ("Ellie", "Tommy"), ("Ellie", "Maria"), ("Ellie", "Dina"), 
    ("Ellie", "Jesse"), ("Ellie", "JJ"), ("Ellie", "Cat"), ("Ellie", "Seth"), ("Ellie", "Riley"), 
    ("Ellie", "Winston"), ("Ellie", "Eugene"), ("Ellie", "Larry"), 
    ("Ellie", "Sean"), ("Ellie", "Regan"), ("Riley", "Winston"),
    ("Ellie", "Shimmer"), ("Ellie", "Abby"), ("Joel", "Sarah"), ("Joel", "Jimmy"), ("Joel", "Tess"), 
    ("Joel", "Ellie"), ("Joel", "Bill"), ("Joel", "Frank"), ("Joel", "Henry"), 
    ("Joel", "Sam"), ("Sarah", "Tommy"), ("Sarah", "Jimmy"), ("Tommy", "Marlene"),
    ("Joel", "Tommy"), ("Tommy", "Buckley"), ("Tommy", "Maria"), ("Tommy", "Eugene2"), ("Dina", "Talia"), 
    ("Dina", "JJ"), ("Dina", "Jesse"), ("Abby", "Jerry"), ("Abby", "Owen"), ("Abby", "Mel"), 
    ("Abby", "Owen"), ("Abby", "Marlene"), ("Abby", "Nora"), ("Abby", "Whitney"), 
    ("Abby", "Jordan"), ("Abby", "Manny"), ("Abby", "Nick"), ("Abby", "Alice"), ("Abby", "Bear"), 
    ("Abby", "Isaac"), ("Abby", "Lev"), ("Abby", "Yara"), ("Owen", "Mel"), ("Owen", "Manny"), 
    ("Owen", "Jerry"), ("Owen", "Nora"), ("Owen", "Many"), ("Owen", "Whitney"), ("Owen", "Alice"), 
    ("Owen", "Jordan"), ("Owen", ",Manny"), ("Owen", "Nick"), ("Mel", "Nora"),
    ("Mel", "Jerry"), ("Mel", "Whitney"), ("Mel", "Jordan"), ("Mel", "Manny"), 
    ("Mel", "Alice"), ("Nora", "Whitney"), ("Nora", "Jordan"), ("Nora", "Manny"), 
    ("Nora", "Nick"), ("Whitney", "Jordan"), ("Whitney", "Manny"), ("Whitney", "Nick"),
    ("Jordan", "Manny"), ("Jordan", "Nick"), ("Jordan", "Leah"), ("Alice", "Bear"), 
    ("Isaac", "Emma"),  ("Isaac", "Alison"),  ("Isaac", "Marcus"),  ("Isaac", "Luis"),
    ("Isaac", "Hugo"), ("Emma", "Alison"), ("Emma", "Marcus"), ("Emma", "Luis"),
    ("Emma", "Hugo"), ("Alison", "Marcus"), ("Alison", "Luis"), ("Alison", "Hugo"),
    ("Marcus", "Luis"), ("Marcus", "Hugo"), ("Luis", "Hugo"), ("Lev", "Yara"),
    ("Lev", "Madre L. y Y."), ("Lev", "Mel"), ("Lev", "Owen"), ("Lev", "Alice"),
    ("Lev", "Clan Víbora"), ("Yara", "Madre L. y Y."), ("Yara", "Mel"), ("Yara", "Owen"), 
    ("Yara", "Alice"), ("Lev", "Serafitas"), ("Yara", "Serafitas"), 
    ("Madre L. y Y.", "Serafitas"), ("Tess", "Robert"), ("Tess", "Bill"), 
    ("Robert", "Marlene"), ("Marlene", "Anna"), ("Marlene", "Ellie"), 
    ("Marlene", "Ethan"), ("Marlene", "Jerry"), ("Marlene", "Kari"), 
    ("Anna", "Ellie"), ("Ellie", "Callus"), ("Ellie", "David"), 
    ("Ellie", "Tess"), ("Bill", "Frank"), ("Henry", "Sam"), 
    ("Maria", "Seth"), ("David", "James"), ("David", "Scully"), 
    ("Jerry", "Ethan"), ("Jerry", "Kari"), ("Eugene1", "Sean"), ("Eugene1", "Regan"), 
    ("Eugene1", "Larry"), ("Sean", "Eugene1"), ("Sean", "Regan"), ("Regan", "Eugene1"), 
    ("Regan", "Sean"), ("Regan", "Larry"), ("Larry", "Eugene1"), ("Winston", "Princesa")
    
])

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(TheLastofUsF, seed=42)
nx.draw(TheLastofUsF, pos, with_labels=True, node_color="green", node_size=1100, font_color="white", font_size=8, edge_color="gray")
plt.title('Grafo de Personajes de The Last of Us Final')
plt.show()

# %%
list(TheLastofUsF.nodes())
# Out:
# ['Joel',
#  'Sarah',
#  'Tommy',
#  'Jimmy',
#  'Tess',
#  'Robert',
#  'Marlene',
#  'Anna',
#  'Ellie',
#  'Bill',
#  'Frank',
#  'Henry',
#  'Sam',
#  'Maria',
#  'Seth',
#  'Buckley',
#  'Callus',
#  'David',
#  'James',
#  'Scully',
#  'Ethan',
#  'Jerry',
#  'Kari',
#  'Riley',
#  'Winston',
#  'Princesa',
#  'Eugene1',
#  'Larry',
#  'Sean',
#  'Regan',
#  'Dina',
#  'Talia',
#  'JJ',
#  'Jesse',
#  'Cat',
#  'Eugene2',
#  'Shimmer',
#  'Abby',
#  'Owen',
#  'Mel',
#  'Nora',
#  'Whitney',
#  'Jordan',
#  'Manny',
#  'Nick',
#  'Leah',
#  'Alice',
#  'Bear',
#  'Isaac',
#  'Emma',
#  'Alison',
#  'Marcus',
#  'Luis',
#  'Hugo',
#  'Lev',
#  'Yara',
#  'Madre L. y Y.',
#  'Serafitas',
#  'Clan Víbora',
#  'Eugene',
#  'Many',
#  ',Manny']

# %%
list(TheLastofUsF.edges())
# Out:
# [('Joel', 'Ellie'),
#  ('Joel', 'Sarah'),
#  ('Joel', 'Jimmy'),
#  ('Joel', 'Tess'),
#  ('Joel', 'Bill'),
#  ('Joel', 'Frank'),
#  ('Joel', 'Henry'),
#  ('Joel', 'Sam'),
#  ('Joel', 'Tommy'),
#  ('Sarah', 'Tommy'),
#  ('Sarah', 'Jimmy'),
#  ('Tommy', 'Ellie'),
#  ('Tommy', 'Marlene'),
#  ('Tommy', 'Buckley'),
#  ('Tommy', 'Maria'),
#  ('Tommy', 'Eugene2'),
#  ('Tess', 'Robert'),
#  ('Tess', 'Bill'),
#  ('Tess', 'Ellie'),
#  ('Robert', 'Marlene'),
#  ('Marlene', 'Abby'),
#  ('Marlene', 'Anna'),
#  ('Marlene', 'Ellie'),
#  ('Marlene', 'Ethan'),
#  ('Marlene', 'Jerry'),
#  ('Marlene', 'Kari'),
#  ('Anna', 'Ellie'),
#  ('Ellie', 'Maria'),
#  ('Ellie', 'Dina'),
#  ('Ellie', 'Jesse'),
#  ('Ellie', 'JJ'),
#  ('Ellie', 'Cat'),
#  ('Ellie', 'Seth'),
#  ('Ellie', 'Riley'),
#  ('Ellie', 'Winston'),
#  ('Ellie', 'Eugene'),
#  ('Ellie', 'Larry'),
#  ('Ellie', 'Sean'),
#  ('Ellie', 'Regan'),
#  ('Ellie', 'Shimmer'),
#  ('Ellie', 'Abby'),
#  ('Ellie', 'Callus'),
#  ('Ellie', 'David'),
# ...

# %%
list(TheLastofUsF.adj["Ellie"])
# Out:
# ['Joel',
#  'Tommy',
#  'Maria',
#  'Dina',
#  'Jesse',
#  'JJ',
#  'Cat',
#  'Seth',
#  'Riley',
#  'Winston',
#  'Eugene',
#  'Larry',
#  'Sean',
#  'Regan',
#  'Shimmer',
#  'Abby',
#  'Marlene',
#  'Anna',
#  'Callus',
#  'David',
#  'Tess']

# %%
list(TheLastofUsF.adj["Abby"])
# Out:
# ['Ellie',
#  'Jerry',
#  'Owen',
#  'Mel',
#  'Marlene',
#  'Nora',
#  'Whitney',
#  'Jordan',
#  'Manny',
#  'Nick',
#  'Alice',
#  'Bear',
#  'Isaac',
#  'Lev',
#  'Yara']

# %%
list(TheLastofUsF.neighbors("Joel"))
# Out:
# ['Ellie', 'Sarah', 'Jimmy', 'Tess', 'Bill', 'Frank', 'Henry', 'Sam', 'Tommy']

# %%
dict(nx.eccentricity(TheLastofUsF))
# Out:
# {'Joel': 4,
#  'Sarah': 5,
#  'Tommy': 4,
#  'Jimmy': 5,
#  'Tess': 4,
#  'Robert': 4,
#  'Marlene': 3,
#  'Anna': 4,
#  'Ellie': 3,
#  'Bill': 5,
#  'Frank': 5,
#  'Henry': 5,
#  'Sam': 5,
#  'Maria': 4,
#  'Seth': 4,
#  'Buckley': 5,
#  'Callus': 4,
#  'David': 4,
#  'James': 5,
#  'Scully': 5,
#  'Ethan': 4,
#  'Jerry': 4,
#  'Kari': 4,
#  'Riley': 4,
#  'Winston': 4,
#  'Princesa': 5,
#  'Eugene1': 5,
#  'Larry': 4,
#  'Sean': 4,
#  'Regan': 4,
#  'Dina': 4,
#  'Talia': 5,
#  'JJ': 4,
#  'Jesse': 4,
#  'Cat': 4,
#  'Eugene2': 5,
#  'Shimmer': 4,
#  'Abby': 3,
#  'Owen': 4,
#  'Mel': 4,
#  'Nora': 4,
#  'Whitney': 4,
#  'Jordan': 4,
#  'Manny': 4,
#  'Nick': 4,
#  'Leah': 5,
#  'Alice': 4,
#  'Bear': 4,
#  'Isaac': 4,
#  'Emma': 5,
#  'Alison': 5,
#  'Marcus': 5,
#  'Luis': 5,
#  'Hugo': 5,
#  'Lev': 4,
#  'Yara': 4,
#  'Madre L. y Y.': 5,
#  'Serafitas': 5,
#  'Clan Víbora': 5,
#  'Eugene': 4,
#  'Many': 5,
#  ',Manny': 5}

# %% [markdown]
# #### Visualizar radio

# %%
radio = (nx.radius(TheLastofUsF))

print(f'El radio del grafo es: {radio}')
# Out:
# El radio del grafo es: 3

# %% [markdown]
# #### Visualizar diametro

# %%
diametro = (nx.diameter(TheLastofUsF))

print(f'El diametro del grafo es: {diametro}')
# Out:
# El diametro del grafo es: 5

# %% [markdown]
# #### Visualizar centro

# %%
center = (nx.center(TheLastofUsF))

print(f'El centro del grafo es: {centro}')
# Out:
# El centro del grafo es: ['Ellie', 'Abby']

# %% [markdown]
# ## Conclusión
#
# Un grafo es una estructura matemática que consiste en un conjunto de nodos (vértices) conectados por arcos (bordes). En el contexto de conectar personajes dentro de una historia, un grafo puede ser utilizado para representar las relaciones y conexiones entre ellos de manera visual y estructurada.
#
# Un grafo puede representar visualmente cómo están conectados los personajes entre sí. Cada personaje puede ser un nodo, y las conexiones entre ellos (amistad, enemistad, parentesco, etc.) pueden ser representadas por arcos entre los nodos.
#
# Utilizando técnicas de análisis de redes sociales, un grafo puede revelar quiénes son los personajes más centrales (más conectados) y quiénes están más aislados en la trama. Esto puede ayudar a los escritores a enfocarse en las relaciones más importantes o subrayar la importancia de ciertos personajes en la historia.
#
# Al mapear las conexiones entre personajes, los escritores pueden visualizar cómo se entrelazan diferentes tramas y subtramas. Esto facilita la planificación y la gestión de la complejidad narrativa al asegurarse de que cada relación y cada personaje tenga un propósito claro en la historia.
#
# En resumen, un grafo es una herramienta poderosa para visualizar y gestionar las complejas relaciones entre personajes dentro de una historia. Ayuda a los escritores a estructurar y desarrollar narrativas de manera más efectiva, asegurando que cada personaje y cada conexión contribuyan de manera significativa al desarrollo general de la trama.
